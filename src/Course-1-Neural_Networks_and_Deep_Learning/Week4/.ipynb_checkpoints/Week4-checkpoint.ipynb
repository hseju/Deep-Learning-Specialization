# %% [markdown]
# # WEEK 4

# %% [markdown]
# ### Deep Neural Network
#
# In deep neural network we will have more than one hidden layer unlike the two layer Neural network we worked with in the Week 3 sessions. The computaion process by far remains the same however the complexity increases with the increase in hidden layers. It is also important to correctly identify the matrices and its shapes for each of the parameter to form a deep neural network.
#
# See an example below of a 3 layer neural network, 3 layers just for the simplicity of the problem.
#
# ![image.png](attachment:0ddd8f4f-6e1d-4e90-a108-b60eb5db398e.png)
#
#
# ![image.png](attachment:08e9c5be-a959-4ed3-b16e-a4c67f812000.png)
